# %% [markdown]
# # Notebook for rmats output of RNU5A-1 project: n.40_41insA

# %%
# %run rmats-function.ipynb
# %run rmats-function-dev.ipynb

# %%
#Define parameters
path = 'path_to_rmats_output'
path41 = 'path_to_rmats_output_with_additional_samples'

#21CTR
listsamples = ['RNU5.1','RNU5.2','CTR.1','CTR.2','CTR.3','CTR.4','CTR.5','CTR.6','CTR.7','CTR.8','CTR.9','CTR.10','CTR.11','CTR.12','CTR.13','CTR.14','CTR.15','CTR.16','CTR.17','CTR.18','CTR.19','CTR.20','CTR.21']
#41CTR
listsamples_41 = ['RNUR.1','RNUR.2','RNUR.3','RNUR.4','RNUR.5','RNUR.6','RNUR.7','RNUR.8','RNUR.9','RNUR.10','RNUR.11','RNUR.12','RNUR.13','RNUR.14','RNUR.15','RNUR.16','RNUR.17','RNUR.18','RNUR.19','RNU.20','RNU.21','RNU.22','RNU.23','sample.1','RNU.24','CTR.1','CTR.2','CTR.3','CTR.4','CTR.5','CTR.6','CTR.7','CTR.8','CTR.9','CTR.10','CTR.11','CTR.12','CTR.13','CTR.14','CTR.15','CTR.16','CTR.17','CTR.18','CTR.19','CTR.20','CTR.21','CTR.22','CTR.23','CTR.24','CTR.25','CTR.26','CTR.27','CTR.28','CTR.29','CTR.30','CTR.31','CTR.32','CTR.33','CTR.34','CTR.35','CTR.36','CTR.37','CTR.38','CTR.39','CTR.40','CTR.41']

# %% [markdown]
# ## 1) Results for use of alternative 5' sites

# %%
infile = path + 'A5SS.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = []

# Get parameters for rmats filtering
mean_cov = 7
FDR = 0.01
delta = 0.05

# Call function for filtering rmats
result = filter_rmats(infile,outfile,outfilenew,listsamples,FDR,delta,mean_cov,events)

df_5ASS = result[0]
df_new = result[1]
A5SS_gene_keys = result[3]

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df(df_5ASS,listsamples,showNames,svgout,FDR,delta)
# Out:
# Number of inframe events: 160, number of out-of-frame events: 148 in 251 genes

# %% [markdown]
#  ### Testing of 5' splice site signature with 20 additional controls, 19 RNU4-2 and 5 other U5 variants

# %%
infile = path41 + 'A5SS.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = result[2]

# Get parameters for rmats filtering
mean_cov = 7
FDR = 2
delta = 0

# Call function for filtering rmats
result_all = filter_rmats_dev(infile,outfile,outfilenew,listsamples_41,FDR,delta,mean_cov,events)

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df_dev(result_all,listsamples_41,showNames,svgout,FDR,delta)

# %% [markdown]
# ## 2) Results for 3' splice sites

# %%
infile = path + 'A3SS.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = []

# Get parameters for rmats filtering
mean_cov = 7
FDR = 0.10
delta = 0.05

# Call function for filtering rmats
result = filter_rmats(infile,outfile,outfilenew,listsamples,FDR,delta,mean_cov,events)

df_3ASS = result[0]

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df(df_3ASS,listsamples,showNames,svgout,FDR,delta)
# Out:
# Number of inframe events: 301, number of out-of-frame events: 0 in 231 genes

# %% [markdown]
# ### Testing of 3' splice site signature with 20 additional controls, 19 RNU4-2 and 5 other U5 variants

# %%
infile = path41 + 'A3SS.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = result[2]

# Get parameters for rmats filtering
mean_cov = 7
FDR = 2
delta = 0

# Call function for filtering rmats
result_all = filter_rmats_dev(infile,outfile,outfilenew,listsamples_41,FDR,delta,mean_cov,events)

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df_dev(result_all,listsamples_41,showNames,svgout,FDR,delta)

# %% [markdown]
# ## 3) Results for exon skipping

# %%
infile = path + 'SE.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = []

# Get parameters for rmats filtering
mean_cov = 7
FDR = 0.10
delta = 0.05

# Call function for filtering rmats
result = filter_rmats(infile,outfile,outfilenew,listsamples,FDR,delta,mean_cov,events)

df_es = result[0]

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df(df_es,listsamples,showNames,svgout,FDR,delta)
# Out:
# Number of inframe events: 207, number of out-of-frame events: 374 in 295 genes

# %% [markdown]
#  ### Testing of exon skipping signature with 20 additional controls, 19 RNU4-2 and 5 other U5 variants

# %%
infile = path41 + 'SE.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = result[2]

# Get parameters for rmats filtering
mean_cov = 7
FDR = 2
delta = 0

# Call function for filtering rmats
result_all = filter_rmats_dev(infile,outfile,outfilenew,listsamples_41,FDR,delta,mean_cov,events)

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df_dev(result_all,listsamples_41,showNames,svgout,FDR,delta)

# %% [markdown]
# ## 4) Results for intronic retention

# %%
infile = path + 'RI.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = []

# Get parameters for rmats filtering
mean_cov = 7
FDR = 0.01
delta = 0.05

# Call function for filtering rmats
result = filter_rmats(infile,outfile,outfilenew,listsamples,FDR,delta,mean_cov,events)

df_ir = result[0]

svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df(df_ir,listsamples,showNames,svgout,FDR,delta)
# Out:
# Number of inframe events: 305, number of out-of-frame events: 152 in 360 genes

# %% [markdown]
#  ### Testing of IR signature with 20 additional controls, 19 RNU4-2 and 5 other U5 variants

# %%
infile = path41 + 'RI.MATS.JCEC.txt'
outfile = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.txt")
outfilenew = infile.replace("JCEC.txt","JCEC.PUROMOINS.sig.new.txt")

events = result[2]

# Get parameters for rmats filtering
mean_cov = 7
FDR = 2
delta = 0

# Call function for filtering rmats
result_all = filter_rmats_dev(infile,outfile,outfilenew,listsamples_41,FDR,delta,mean_cov,events)
svgout = ""  # Output path for saving svg plot
showNames = False  #True of False
#Call PCA function
PCA_df_dev(result_all,listsamples_41,showNames,svgout,FDR,delta)
